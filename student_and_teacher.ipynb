# %% [markdown]
# # Knowledge Distillation against Optical Nerual Networks

# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets

device = (
    torch.accelerator.current_accelerator().type
    if torch.accelerator.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Preprocess Dataset

# %%
transforms_mnist = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.2860,), (0.3530,))]
)

# Loading the MNIST dataset:
train_dataset = datasets.FashionMNIST(
    root="./data", train=True, download=True, transform=transforms_mnist
)
test_dataset = datasets.FashionMNIST(
    root="./data", train=False, download=True, transform=transforms_mnist
)

# %%
#Dataloaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)

# %%
def preprocess_upscale_pad(inputs):
    """
    Common preprocessing for both teacher and ONN models:
    - Upscale from 28x28 to 150x150
    - Pad from 150x150 to 200x200
    """
    # Upscale the images from 28x28 to 150x150
    upscaled = torch.nn.functional.interpolate(inputs, size=(150, 150), mode='bilinear', align_corners=False)
    
    # Pad the images from 150x150 to 200x200
    padded = torch.nn.functional.pad(upscaled, (25, 25, 25, 25))
    
    return padded

def preprocess_for_onn(inputs):
    """
    Convert standard Fashion-MNIST images to the format expected by ONN:
    - Upscale from 28x28 to 150x150
    - Pad from 150x150 to 200x200
    - Add complex dimension (real and imaginary parts)
    """
    # Apply common preprocessing
    padded = preprocess_upscale_pad(inputs)
    
    # Convert from [batch, 1, 200, 200] to [batch, 200, 200]
    padded = padded.squeeze(1)
    
    # Add complex dimension (real part is the image, imaginary part is zeros)
    # Shape becomes [batch, 200, 200, 2]
    complex_input = torch.stack((padded, torch.zeros_like(padded)), dim=-1)
    
    return complex_input

# %%
# test preprocess_for_onn
if __name__ == "__main__":
    # Test the preprocess_for_onn function
    test_images, _ = next(iter(test_loader))
    preprocessed_images = preprocess_for_onn(test_images)
    
    # Show original and preprocessed images
    import matplotlib.pyplot as plt
    fig, axes = plt.subplots(2, 5, figsize=(15, 6))
    for i in range(5):
        axes[0, i].imshow(test_images[i][0], cmap='gray')
        axes[0, i].set_title("Original")
        axes[0, i].axis('off')
        
        axes[1, i].imshow(preprocessed_images[i][:, :, 0], cmap='gray')
        axes[1, i].set_title("Preprocessed")
        axes[1, i].axis('off')

# %% [markdown]
# ## Training a CNN Network as a Teacher Model

# %%
class DeepNN(nn.Module):
    def __init__(self, num_classes=10, use_large_input=False):
        super(DeepNN, self).__init__()
        self.use_large_input = use_large_input
        
        self.features = nn.Sequential(
            nn.Conv2d(1, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # 14x14 or 100x100
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # 7x7 or 50x50
        )
        
        # Add additional pooling for larger input sizes to reduce to manageable feature map size
        if use_large_input:
            self.features.add_module('additional_pool', nn.MaxPool2d(kernel_size=5, stride=5))  # 10x10
            fc_input_size = 32 * 10 * 10  # 3200
        else:
            fc_input_size = 32 * 7 * 7  # 1568
            
        self.classifier = nn.Sequential(
            nn.Linear(fc_input_size, 512),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def train(model, train_loader, epochs, learning_rate, device, preprocess=False):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    model.train()

    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, labels in train_loader:
            # inputs: A collection of batch_size images
            # labels: A vector of dimensionality batch_size with integers denoting class of each image
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Apply preprocessing if requested
            if preprocess:
                inputs = preprocess_upscale_pad(inputs)

            optimizer.zero_grad()
            outputs = model(inputs)

            # outputs: Output of the network for the collection of images. A tensor of dimensionality batch_size x num_classes
            # labels: The actual labels of the images. Vector of dimensionality batch_size
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss / len(train_loader)}")

    os.makedirs("cnn_models", exist_ok=True)
    torch.save(model.state_dict(), "cnn_models/fashion_mnist_model.pth")

def test(model, test_loader, device, preprocess=False):
    model.to(device)
    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Apply preprocessing if requested
            if preprocess:
                inputs = preprocess_upscale_pad(inputs)

            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy

# %%
nn_deep = DeepNN(num_classes=10, use_large_input=True).to(device)

teacher_model_path = "cnn_models/fashion_mnist_model.pth"
if os.path.exists(teacher_model_path):
    print(f"Loading pre-trained teacher model from {teacher_model_path}")
    nn_deep.load_state_dict(torch.load(teacher_model_path))
else:
    print("Training teacher model from scratch")
    train(nn_deep, train_loader, epochs=10, learning_rate=0.001, device=device, preprocess=True)

test_accuracy_deep = test(nn_deep, test_loader, device, preprocess=True)
# Out:
# Loading pre-trained teacher model from cnn_models/fashion_mnist_model.pth
# Test Accuracy: 91.70%

# %%
def train_onn(model, train_loader, epochs, learning_rate, device):
    """
    Train function specifically for the Optical Neural Network (ONN)
    
    Args:
        model: The ONN model
        train_loader: DataLoader for training data
        epochs: Number of training epochs
        learning_rate: Learning rate for optimizer
        device: Device to use for training
    """
    # ONN outputs softmax probabilities directly, so MSE is appropriate
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    model.train()
    epoch_accuracies_history = []
    best_accuracy = 0.0

    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Preprocess inputs for ONN
            onn_inputs = preprocess_for_onn(inputs)
            
            # Convert labels to one-hot encoding for ONN
            labels_one_hot = torch.nn.functional.one_hot(labels, num_classes=10).float()
            
            optimizer.zero_grad()
            
            # Forward pass - ONN outputs softmax probabilities
            outputs = model(onn_inputs)
            
            # Compute loss between softmax outputs and one-hot labels
            loss = criterion(outputs, labels_one_hot)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        epoch_accuracies_history.append(epoch_acc)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")

        # Save the model every epoch
        if not os.path.exists("onn_model"):
            os.makedirs("onn_model")

        if epoch_acc > best_accuracy:
            best_accuracy = epoch_acc
            # Save the model state
            torch.save(model.state_dict(), "onn_model/best_model.pth")
        
        torch.save(model.state_dict(), "onn_model/last.pth")
        
    return model, epoch_accuracies_history

# %%
def test_onn(model, test_loader, device):
    """
    Test function specifically for the Optical Neural Network (ONN)
    
    Args:
        model: The ONN model
        test_loader: DataLoader for test data
        device: Device to use for testing
    """
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            # Preprocess inputs for ONN
            onn_inputs = preprocess_for_onn(inputs)
            
            # Forward pass
            outputs = model(onn_inputs)
            
            # Get predictions
            _, predicted = torch.max(outputs, 1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy

# %% [markdown]
# ## Train ONN without KD
#
# In this section, we will train an ONN network without using knowledge distillation.

# %%
num_epoches = 15

# %%
from onn import Net as ONNNet
onn= ONNNet().to(device)
onn, history_student_no_kd = train_onn(onn, train_loader, epochs=num_epoches, learning_rate=0.001, device=device)
test_accuracy_light_ce = test_onn(onn, test_loader, device)
# Out:
# Epoch 1/15, Loss: 0.0771, Accuracy: 55.78%
# Epoch 2/15, Loss: 0.0614, Accuracy: 65.27%
# Epoch 3/15, Loss: 0.0554, Accuracy: 69.61%
# Epoch 4/15, Loss: 0.0524, Accuracy: 70.89%
# Epoch 5/15, Loss: 0.0507, Accuracy: 71.44%
# Epoch 6/15, Loss: 0.0496, Accuracy: 71.78%
# Epoch 7/15, Loss: 0.0487, Accuracy: 72.08%
# Epoch 8/15, Loss: 0.0481, Accuracy: 72.19%
# Epoch 9/15, Loss: 0.0476, Accuracy: 72.39%
# Epoch 10/15, Loss: 0.0472, Accuracy: 72.51%
# Epoch 11/15, Loss: 0.0469, Accuracy: 72.69%
# Epoch 12/15, Loss: 0.0466, Accuracy: 72.80%
# Epoch 13/15, Loss: 0.0464, Accuracy: 72.87%
# Epoch 14/15, Loss: 0.0462, Accuracy: 72.93%
# Epoch 15/15, Loss: 0.0460, Accuracy: 73.03%
# Test Accuracy: 72.61%

# %%
def train_knowledge_distillation_onn(teacher, student, train_loader, epochs, learning_rate, T, alpha, device):
    """
    Improved knowledge distillation training function
    
    Args:
        teacher: The teacher model
        student: The student model
        train_loader: DataLoader for training data
        epochs: Number of training epochs
        learning_rate: Learning rate for optimizer
        T: Temperature for softening the logits
        alpha: Weight for soft targets loss (1-alpha will be weight for hard targets)
        device: Device to use for training
    """
    optimizer = optim.Adam(student.parameters(), lr=learning_rate)
    
    # Use KL divergence for soft targets and cross-entropy for hard targets
    criterion_kl = nn.KLDivLoss(reduction='batchmean')
    criterion_ce = nn.CrossEntropyLoss()
    
    teacher.eval()  # Teacher set to evaluation mode
    student.train() # Student to train mode
    epoch_accuracies_history = []
    best_accuracy = 0.0
    
    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            
            # Forward pass with the teacher model
            with torch.no_grad():
                teacher_inputs = preprocess_upscale_pad(inputs)
                teacher_outputs = teacher(teacher_inputs)
                
                # Apply temperature and convert to probabilities
                soft_targets = nn.functional.softmax(teacher_outputs / T, dim=1)
            
            # Preprocess inputs for ONN
            onn_inputs = preprocess_for_onn(inputs)
            
            # Forward pass with the student model - outputs are already probabilities
            student_outputs = student(onn_inputs)
            
            # For KL divergence, we need to take log of student outputs
            # Note: This is different from standard KL div with logits
            log_student_outputs = torch.log(student_outputs + 1e-8)  # Add small epsilon to prevent log(0)
            
            # KL divergence loss
            loss_kd = criterion_kl(log_student_outputs, soft_targets) * (T * T)
            
            # Standard cross-entropy loss with one-hot encoded labels
            labels_one_hot = torch.nn.functional.one_hot(labels, num_classes=10).float()
            loss_ce = criterion_ce(student_outputs, labels_one_hot)
            
            # Combined loss with alpha as weight
            loss = (alpha * loss_kd) + ((1 - alpha) * loss_ce)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            # Calculate accuracy
            _, predicted = torch.max(student_outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        # Calculate and print epoch statistics
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        epoch_accuracies_history.append(epoch_acc)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")
        
        # Save the model
        if not os.path.exists("onn_student"):
            os.makedirs("onn_student")
            
        if epoch_acc > best_accuracy:
            best_accuracy = epoch_acc
            torch.save(student.state_dict(), "onn_student/best.pth")
            
        torch.save(student.state_dict(), "onn_student/last.pth")
    
    return student, epoch_accuracies_history

# %%
num_epoches_kd = 15

# %%
new_onn = ONNNet().to(device)
new_onn, history_student_kd = train_knowledge_distillation_onn(
    teacher=nn_deep, 
    student=new_onn, 
    train_loader=train_loader, 
    epochs=num_epoches_kd, 
    learning_rate=0.001,
    T=4, 
    alpha=0.7,
    device=device
)
test_accuracy_light_ce_and_kd = test_onn(new_onn, test_loader, device)

# Compare the student test accuracy with and without the teacher, after distillation
print(f"Teacher accuracy: {test_accuracy_deep:.2f}%")
print(f"Student accuracy without teacher: {test_accuracy_light_ce:.2f}%")
print(f"Student accuracy with CE + KD: {test_accuracy_light_ce_and_kd:.2f}%")
# Out:
# Epoch 1/15, Loss: 14.3945, Accuracy: 59.05%
# Epoch 2/15, Loss: 10.1581, Accuracy: 65.89%
# Epoch 3/15, Loss: 8.7013, Accuracy: 69.06%
# Epoch 4/15, Loss: 8.0045, Accuracy: 70.45%
# Epoch 5/15, Loss: 7.5960, Accuracy: 71.20%
# Epoch 6/15, Loss: 7.3245, Accuracy: 71.75%
# Epoch 7/15, Loss: 7.1290, Accuracy: 72.22%
# Epoch 8/15, Loss: 6.9818, Accuracy: 72.53%
# Epoch 9/15, Loss: 6.8674, Accuracy: 72.83%
# Epoch 10/15, Loss: 6.7764, Accuracy: 73.00%
# Epoch 11/15, Loss: 6.7012, Accuracy: 73.13%
# Epoch 12/15, Loss: 6.6399, Accuracy: 73.35%
# Epoch 13/15, Loss: 6.5875, Accuracy: 73.48%
# Epoch 14/15, Loss: 6.5432, Accuracy: 73.55%
# Epoch 15/15, Loss: 6.5044, Accuracy: 73.80%
# Test Accuracy: 72.70%
# Teacher accuracy: 91.70%
# Student accuracy without teacher: 72.61%
# Student accuracy with CE + KD: 72.70%

# %%
import matplotlib.pyplot as plt

epochs_range = range(1, num_epoches + 1)
epochs_range_kd = range(1, num_epoches_kd + 1)

plt.figure(figsize=(12, 7))
plt.plot(epochs_range, history_student_no_kd, label='Student ONN (Training Accuracy w/o KD)', marker='o', linestyle='-')
plt.plot(epochs_range_kd, history_student_kd, label='Student ONN (Training Accuracy w/ KD)', marker='x', linestyle='--')

plt.title('Student ONN Training Accuracy Comparison')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)
plt.ylim(bottom=min(min(history_student_no_kd), min(history_student_kd)) - 5, top=max(max(history_student_no_kd), max(history_student_kd)) + 5)
plt.tight_layout()
plt.show()
